# %% [markdown]
# # Veronica Sanchez Molina
# * 2024/02/09

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# matplotlib qt

# %%
nums = np.random.uniform(0,1,1000)

# %%
plt.hist(nums, bins=100)
plt.xlabel("Region")
plt.ylabel("Density Scale")
plt.savefig("prompt9.pdf", dpi = 300)
plt.show()
