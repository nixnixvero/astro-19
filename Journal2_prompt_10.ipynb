# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
nums = np.random.normal(loc=5, scale=1.5, size=1000)

# %%
plt.hist(nums, bins=100)
plt.xlabel("Product")
plt.ylabel("Price")
plt.savefig("prompt10.pdf", dpi=300)
plt.show()
